# %%
import pandas as pd
import numpy as np

data = pd.read_csv("../week2/Dataset/student.csv")

df = pd.DataFrame(data)

df.head()
# Out:
#    Math  Reading  Writing
# 0    48       68       63
# 1    62       81       72
# 2    79       80       78
# 3    76       83       79
# 4    59       64       62

# %%
def cost_function(X, Y, W):

    
    m = len(Y)
    y_predict = np.dot(X, W)
    cost = (1/2*m) * np.sum(np.square(y_predict-Y))

    return cost

# %%
X_test = np.array([[1, 2], [3, 4], [5, 6]])
Y_test = np.array([3, 7, 11])
W_test = np.array([1, 1])

cost = cost_function(X_test, Y_test, W_test)

if cost == 0:
    print("Proceed Further")
else:
    print("something went wrong: Reimplement a cost function")
    print("Cost function output:", cost_function(X_test, Y_test, W_test))
# Out:
# Proceed Further

# %%
# derivative = (loss.x)/m


def gradient_descent(x, y, w, alpha, iterations ):

    cost_history = [0] * iterations

    m = len(y)
    for i in range(iterations):
        y_predict = np.dot(x, w)
        loss = y_predict - y
        dw = np.dot(loss , x)/m
        w_update = w - (alpha*dw)
        cost = cost_function(x, y, w_update)
        cost_history[i] = cost
    return w_update, cost_history

# %%
# Generate random test data
np.random.seed(0) # For reproducibility
X = np.random.rand(100, 3) # 100 samples, 3 features
Y = np.random.rand(100)
W = np.random.rand(3) # Initial guess for parameters
# Set hyperparameters
alpha = 0.01
iterations = 1000
# Test the gradient_descent function
final_params, cost_history = gradient_descent(X, Y, W, alpha, iterations)
# Print the final parameters and cost history
print("Final Parameters:", final_params)
print("Cost History:", cost_history)
# Out:
# Final Parameters: [0.3996496  0.92745322 0.09826523]
# ...

# %%
def rmse(y, y_predict):
    n = len(y)
    rmse = np.sqrt(np.sum(np.square(y-y_predict)))
    return rmse

# %%
def r2(y, y_predict):
    mean_y = np.mean(y)
    ss_tot = np.sum(np.square(y-mean_y))
    ss_res = np.sum(np.square(y-y_predict))

    r2 = 1 - (ss_res/ss_tot)
    return r2

# %%
def train_test_split(x, y, test_size =0.3, random_seed = 42 ):

    np.random.seed(random_seed)
    indices = np.arange(x.shape[0])
    test_split_size = int(len(x) * test_size)
    test_indices = indices[:test_split_size]
    train_indices = indices[test_split_size:]
    x_train, x_test = x[train_indices], x[test_indices]
    y_train, y_test = y[train_indices], y[test_indices]
    return x_train, x_test, y_train, y_test

# %%
def main():

    data = pd.read_csv("../week2/Dataset/student.csv")
    
    x = data[['Math', 'Reading']].values
    y = data['Writing'].values
    
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_seed=42 )

    w = np.zeros(x_train.shape[1])
    alpha = 1e-4
    iterations = 1000

    w_update, cost_history = gradient_descent(x_train, y_train, w, alpha, iterations)

    y_predict = np.dot(x_test, w_update)

    model_rmse = rmse(y_test, y_predict)
    model_r2 = r2(y_test, y_predict)

    print(f'W update: {w_update} ')
    print(f'cost history first 10 interations: {cost_history[:10]}')
    print(f'RMSE on test set: {model_rmse}')
    print(f'R2 test set: {model_r2}')


if __name__ == "__main__" :
    main()
# Out:
# W update: [0.48149825 0.4991655 ]
# cost history first 10 interations: [np.float64(11403504.027751377), np.float64(11403504.027751377), np.float64(11403504.027751377), np.float64(11403504.027751377), np.float64(11403504.027751377), np.float64(11403504.027751377), np.float64(11403504.027751377), np.float64(11403504.027751377), np.float64(11403504.027751377), np.float64(11403504.027751377)]
# RMSE on test set: 88.29401323867565
# R2 test set: 0.8087779388931982
