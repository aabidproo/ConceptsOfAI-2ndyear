# %%
import pandas as pd

dataset = pd.read_csv("Dataset/medical_students_dataset.csv")

df = pd.DataFrame(dataset)

df.head()
# Out:
#    Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0         1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1         2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2         3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3         NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4         5.0  23.0  Female         NaN  46.234173          O        NaN
#
#    Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 0          NaN        95.0           109.0        203.0       No     NaN
# 1    98.714977        93.0           104.0        163.0       No      No
# 2    98.260293        76.0           130.0        216.0      Yes      No
# 3    98.839605        99.0           112.0        141.0       No     Yes
# 4    98.480008        95.0             NaN        231.0       No      No

# %%
df.describe()
# Out:
#           Student ID            Age         Height         Weight  \
# count  180000.000000  180000.000000  180000.000000  180000.000000
# mean    49974.042078      26.021561     174.947103      69.971585
# std     28879.641657       4.890528      14.447560      17.322574
# min         1.000000      18.000000     150.000041      40.000578
# 25%     24971.750000      22.000000     162.476110      54.969838
# 50%     49943.500000      26.000000     174.899914      69.979384
# 75%     74986.000000      30.000000     187.464417      84.980097
# max    100000.000000      34.000000     199.998639      99.999907
#
#                  BMI    Temperature     Heart Rate  Blood Pressure  \
# count  180000.000000  180000.000000  180000.000000   180000.000000
# mean       23.338869      98.600948      79.503767      114.558033
# std         7.033554       0.500530      11.540755       14.403353
# min        10.074837      96.397835      60.000000       90.000000
# ...

# %%
df.head()
# Out:
#    Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0         1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1         2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2         3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3         NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4         5.0  23.0  Female         NaN  46.234173          O        NaN
#
#    Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 0          NaN        95.0           109.0        203.0       No     NaN
# 1    98.714977        93.0           104.0        163.0       No      No
# 2    98.260293        76.0           130.0        216.0      Yes      No
# 3    98.839605        99.0           112.0        141.0       No     Yes
# 4    98.480008        95.0             NaN        231.0       No      No

# %%
df[["Age", "Gender"]]
# Out:
#          Age  Gender
# 0       18.0  Female
# 1        NaN    Male
# 2       32.0  Female
# 3       30.0    Male
# 4       23.0  Female
# ...      ...     ...
# 199995  24.0    Male
# 199996  29.0  Female
# 199997  34.0  Female
# 199998  30.0  Female
# 199999  20.0  Female
#
# [200000 rows x 2 columns]

# %%
df_without_age = df.drop(columns="Age")

# %%
df_without_age
# Out:
#         Student ID  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0    Male  152.069157  47.630941          B        NaN
# 2              3.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN    Male  182.112867  63.332207          B  19.096042
# 4              5.0  Female         NaN  46.234173          O        NaN
# ...            ...     ...         ...        ...        ...        ...
# 199995         NaN    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  Female  153.927409  99.928405          O  42.175189
#
#         Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# ...

# %%
df.drop(index=0)
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# 5              6.0  32.0     NaN  151.491294  68.647805          B  29.912403
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
# ...

# %%
df["Weight(Pound)"] = df["Weight"]*2.2

# %%
df
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
# ...

# %%
df["Height(Ft)"] = df["Height"]/30.48

# %%
df
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
# ...

# %%
df.isnull().sum()
# Out:
# Student ID        20000
# Age               20000
# Gender            20000
# Height            20000
# Weight            20000
# Blood Type        20000
# BMI               20000
# Temperature       20000
# Heart Rate        20000
# Blood Pressure    20000
# Cholesterol       20000
# Diabetes          20000
# Smoking           20000
# Weight(Pound)     20000
# Height(Ft)        20000
# dtype: int64

# %%
df
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
# ...

# %%
df[df["Smoking"] == "Yes"]
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 5              6.0  32.0     NaN  151.491294  68.647805          B  29.912403
# 10            11.0  28.0  Female  152.973928  73.572814          B  31.440000
# 12            13.0  29.0    Male  168.845992  48.533565         AB        NaN
# 14            15.0  33.0    Male  184.718988  93.666944        NaN  27.451322
# ...            ...   ...     ...         ...        ...        ...        ...
# 199980     99981.0   NaN    Male  184.247859        NaN          O  24.569819
# 199982     99983.0  21.0  Female  171.770897        NaN          O  31.855816
# 199985     99986.0  23.0  Female  162.884951  82.485778          B  31.089745
# 199990     99991.0  21.0  Female  183.735110  51.172076         AB  15.158238
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
#
# ...

# %%
df[df["Smoking"] == "No"]
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# 6              7.0  21.0     NaN  172.949704  48.102744         AB  16.081635
# 7              8.0  28.0    Male  186.489402  52.389752         AB  15.063921
# ...            ...   ...     ...         ...        ...        ...        ...
# 199993     99994.0  22.0    Male         NaN  46.155224          A        NaN
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Student ID      180000 non-null  float64
#  1   Age             180000 non-null  float64
#  2   Gender          180000 non-null  object
#  3   Height          180000 non-null  float64
#  4   Weight          180000 non-null  float64
#  5   Blood Type      180000 non-null  object
#  6   BMI             180000 non-null  float64
#  7   Temperature     180000 non-null  float64
#  8   Heart Rate      180000 non-null  float64
#  9   Blood Pressure  180000 non-null  float64
#  10  Cholesterol     180000 non-null  float64
#  11  Diabetes        180000 non-null  object
#  12  Smoking         180000 non-null  object
# dtypes: float64(9), object(4)
# memory usage: 19.8+ MB

# %%
df[df["Blood Type"] == "A"]
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 34            35.0  33.0    Male  160.463706  55.755226          A  21.653691
# 49            50.0   NaN  Female  153.791479        NaN          A  33.675388
# 57            58.0  25.0     NaN  170.307975        NaN          A        NaN
# 59            60.0  30.0    Male  182.241692  48.609045          A        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199986     99987.0  34.0    Male  165.651315  93.099756          A  33.928040
# 199991     99992.0  28.0    Male  183.499177        NaN          A  26.527962
# 199993     99994.0  22.0    Male         NaN  46.155224          A        NaN
# 199994     99995.0  22.0    Male  159.486907        NaN          A  27.631082
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
#
# ...

# %%
df[~df["Gender"].isin(["Male", "Female"])]
# Out:
#         Student ID   Age Gender      Height     Weight Blood Type        BMI  \
# 5              6.0  32.0    NaN  151.491294  68.647805          B  29.912403
# 6              7.0  21.0    NaN  172.949704  48.102744         AB  16.081635
# 9             10.0  32.0    NaN  170.836315  50.783250          B  17.400435
# 17            18.0  27.0    NaN  176.694741  56.243559          O  18.014638
# 28            29.0   NaN    NaN         NaN  82.826786        NaN  32.276465
# ...            ...   ...    ...         ...        ...        ...        ...
# 199968     99969.0  26.0    NaN  150.980841  70.732659          B  31.029609
# 199976     99977.0  18.0    NaN  164.968011  46.577873          O  17.115129
# 199984     99985.0   NaN    NaN  169.246287  63.738430        NaN  22.251693
# 199987     99988.0  33.0    NaN  169.061017  56.401454         AB  19.733465
# 199988     99989.0  28.0    NaN  160.443722  55.688170          O  21.633037
#
# ...

# %%
df.loc[df["Age"] == "NaN", "Age"] = "Others"
# Out:
# /var/folders/yx/x88lcnsd4p1bzqmbyq5p6str0000gn/T/ipykernel_2587/853585219.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Others' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df["Age"] == "NaN", "Age"] = "Others"

# %%
df.loc[df['Age'] == "NaN"]
# Out:
# Empty DataFrame
# Columns: [Student ID, Age, Gender, Height, Weight, Blood Type, BMI, Temperature, Heart Rate, Blood Pressure, Cholesterol, Diabetes, Smoking]
# Index: []

# %%
df.loc[df['Age'] == "Others"]
# Out:
# Empty DataFrame
# Columns: [Student ID, Age, Gender, Height, Weight, Blood Type, BMI, Temperature, Heart Rate, Blood Pressure, Cholesterol, Diabetes, Smoking]
# Index: []

# %%
set(df["Age"])
# Out:
# {nan,
#  nan,
#  18.0,
#  19.0,
#  20.0,
#  21.0,
#  22.0,
#  23.0,
#  24.0,
#  25.0,
#  26.0,
#  27.0,
#  28.0,
#  29.0,
#  30.0,
#  31.0,
#  32.0,
#  33.0,
#  34.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
df.head()
# Out:
#    Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0         1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1         2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2         3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3         NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4         5.0  23.0  Female         NaN  46.234173          O        NaN
#
#    Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 0          NaN        95.0           109.0        203.0       No     NaN
# 1    98.714977        93.0           104.0        163.0       No      No
# 2    98.260293        76.0           130.0        216.0      Yes      No
# 3    98.839605        99.0           112.0        141.0       No     Yes
# 4    98.480008        95.0             NaN        231.0       No      No

# %%
df.loc[df["Age"] == "Others"]
# Out:
# Empty DataFrame
# Columns: [Student ID, Age, Gender, Height, Weight, Blood Type, BMI, Temperature, Heart Rate, Blood Pressure, Cholesterol, Diabetes, Smoking]
# Index: []

# %%
df.loc[df["Gender"] == "Female", "Gender"] = "female"

# %%
df.loc[df["Gender"] =="female", "Gender"] = "Female"

# %%
set(df["Gender"])
# Out:
# {'Female', 'Male', nan}

# %%
df[df["Gender"] == "Female"]
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# 10            11.0  28.0  Female  152.973928  73.572814          B  31.440000
# 11            12.0  34.0  Female  182.416302  76.371050         AB  22.950992
# ...            ...   ...     ...         ...        ...        ...        ...
# 199990     99991.0  21.0  Female  183.735110  51.172076         AB  15.158238
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
# ...

# %%
df.loc[df["Gender"] == "Female"]
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# 10            11.0  28.0  Female  152.973928  73.572814          B  31.440000
# 11            12.0  34.0  Female  182.416302  76.371050         AB  22.950992
# ...            ...   ...     ...         ...        ...        ...        ...
# 199990     99991.0  21.0  Female  183.735110  51.172076         AB  15.158238
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
# ...

# %%
df["Gender"] = df["Gender"].str.upper()

# %%
df["Gender"]
# Out:
# 0         FEMALE
# 1           MALE
# 2         FEMALE
# 3           MALE
# 4         FEMALE
#            ...
# 199995      MALE
# 199996    FEMALE
# 199997    FEMALE
# 199998    FEMALE
# 199999    FEMALE
# Name: Gender, Length: 200000, dtype: object

# %%
df.tail()
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 199995         NaN  24.0    MALE  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  FEMALE  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  FEMALE         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  FEMALE  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  FEMALE  153.927409  99.928405          O  42.175189
#
#         Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 199995    99.170685        65.0           121.0        130.0       No      No
# 199996    97.865785        62.0           125.0        198.0       No     Yes
# 199997    98.768210        60.0            90.0        154.0      NaN      No
# 199998    98.994212        61.0           106.0        225.0       No      No
# 199999    98.595817        95.0           133.0        132.0      NaN      No

# %%
df = df.drop(199999)

# %%
df.rename(columns={"Student ID":"Student Id"}, inplace=True)

# %%
df
# Out:
#         Student Id   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  FEMALE  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    MALE  152.069157  47.630941          B        NaN
# 2              3.0  32.0  FEMALE  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    MALE  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  FEMALE         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199994     99995.0  22.0    MALE  159.486907        NaN          A  27.631082
# 199995         NaN  24.0    MALE  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  FEMALE  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  FEMALE         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  FEMALE  156.446944  50.142824          A  20.486823
#
# ...

# %%
df.shape
# Out:
# (199999, 13)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# MALE      90005
# FEMALE    89994
# Name: count, dtype: int64

# %%
df["Blood Type"].value_counts()
# Out:
# Blood Type
# B     45537
# O     45510
# AB    44486
# A     44466
# Name: count, dtype: int64

# %%
df["Smoking"].value_counts()
# Out:
# Smoking
# No     143970
# Yes     36029
# Name: count, dtype: int64

# %%
df.groupby("Gender")["Heart Rate"].mean()
# Out:
# Gender
# FEMALE    79.562583
# MALE      79.429758
# Name: Heart Rate, dtype: float64

# %%
df.to_csv("medical_student2.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199999 entries, 0 to 199998
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Student Id      179999 non-null  float64
#  1   Age             179999 non-null  object
#  2   Gender          179999 non-null  object
#  3   Height          179999 non-null  float64
#  4   Weight          179999 non-null  float64
#  5   Blood Type      179999 non-null  object
#  6   BMI             179999 non-null  float64
#  7   Temperature     179999 non-null  float64
#  8   Heart Rate      179999 non-null  float64
#  9   Blood Pressure  179999 non-null  float64
#  10  Cholesterol     179999 non-null  float64
#  11  Diabetes        180000 non-null  object
#  12  Smoking         179999 non-null  object
# dtypes: float64(8), object(5)
# memory usage: 19.8+ MB
