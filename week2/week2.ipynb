# %%
import pandas as pd

dataset = pd.read_csv("Dataset/bank.csv")

df = pd.DataFrame(dataset)

df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.tail()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=45211, step=1)

# %%
set(df["job"])
# Out:
# {'admin.',
#  'blue-collar',
#  'entrepreneur',
#  'housemaid',
#  'management',
#  'retired',
#  'self-employed',
#  'services',
#  'student',
#  'technician',
#  'unemployed',
#  'unknown'}

# %%
df[["month", "education"]]
# Out:
#       month  education
# 0       may   tertiary
# 1       may  secondary
# 2       may  secondary
# 3       may    unknown
# 4       may    unknown
# ...     ...        ...
# 45206   nov   tertiary
# 45207   nov    primary
# 45208   nov  secondary
# 45209   nov  secondary
# 45210   nov  secondary
#
# [45211 rows x 2 columns]

# %%
df.iloc[0]["job"]
# Out:
# 'management'

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df[(df["marital"] == "single") & (df["balance"] > 500) & (df["age"] < 30)]
# Out:
#        age         job marital  education default  balance housing loan  \
# 126     29      admin.  single  secondary      no      818     yes  yes
# 509     26      admin.  single  secondary      no      712     yes   no
# 569     28    services  single  secondary      no     5090     yes   no
# 690     29     student  single  secondary      no      948     yes   no
# 890     29     student  single  secondary      no      872     yes   no
# ...    ...         ...     ...        ...     ...      ...     ...  ...
# 45143   28     student  single  secondary      no      970      no   no
# 45148   22     student  single  secondary      no     2488      no   no
# 45188   29  management  single  secondary      no      703     yes   no
# 45192   29  management  single   tertiary      no      765      no   no
# 45205   25  technician  single  secondary      no      505      no  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
df[(df["marital"] == "single") | (df["balance"] > 50000) & (df["age"] < 30)]
# Out:
#        age          job marital  education default  balance housing loan  \
# 1       44   technician  single  secondary      no       29     yes   no
# 4       33      unknown  single    unknown      no        1      no   no
# 6       28   management  single   tertiary      no      447     yes  yes
# 9       43   technician  single  secondary      no      593     yes   no
# 11      29       admin.  single  secondary      no      390     yes   no
# ...    ...          ...     ...        ...     ...      ...     ...  ...
# 45197   36   management  single  secondary      no     1511     yes   no
# 45199   34  blue-collar  single  secondary      no     1475     yes   no
# 45202   34       admin.  single  secondary      no      557      no   no
# 45203   23      student  single   tertiary      no      113      no   no
# 45205   25   technician  single  secondary      no      505      no  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
df[df["campaign"] == 3]
# Out:
#        age           job  marital  education default  balance housing loan  \
# 103     59   blue-collar  married    primary      no      179     yes   no
# 122     34        admin.  married    unknown      no        3     yes   no
# 158     52   blue-collar  married  secondary      no      782     yes   no
# 169     50   blue-collar  married    primary      no        0      no   no
# 217     53    unemployed  married    unknown      no       13      no   no
# ...    ...           ...      ...        ...     ...      ...     ...  ...
# 45161   31    management  married   tertiary      no      720     yes   no
# 45171   33        admin.   single  secondary      no      690      no   no
# 45175   38  entrepreneur   single  secondary      no     2543      no   no
# 45199   34   blue-collar   single  secondary      no     1475     yes   no
# 45206   51    technician  married   tertiary      no      825      no   no
#
# ...

# %%
df.iloc[1223]
# Out:
# age                   26
# job          blue-collar
# marital          married
# education      secondary
# default              yes
# balance               20
# housing              yes
# loan                  no
# contact          unknown
# day                    8
# month                may
# duration             200
# campaign               1
# pdays                 -1
# previous               0
# poutcome         unknown
# y                     no
# Name: 1223, dtype: object
